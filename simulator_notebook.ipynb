# %% [markdown]
# ## Notebook with example usage of library
# In this notebook we will show you how to use our library
#
# First we import the necisary libraries

# %%
import pathlib
import sys
import numpy as np

# %% [markdown]
# Now we import our library

# %%
from nqubitsim import gates
from nqubitsim.simulator import QuantumSimulator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from nqubitsim import gates
#       2 from nqubitsim.simulator import QuantumSimulator
#
# ModuleNotFoundError: No module named 'nqubitsim'
